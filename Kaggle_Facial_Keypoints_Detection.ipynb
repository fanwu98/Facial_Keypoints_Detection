# %% [markdown]
# <a href="https://colab.research.google.com/github/fanwu98/Facial_Keypoints_Detection/blob/main/Kaggle_Facial_Keypoints_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/kaggle/facial_keypoints_detection/facial-keypoints-detection.zip -d kaggle/facial_keypoints_detection
# Out:
# Archive:  /content/kaggle/facial_keypoints_detection/facial-keypoints-detection.zip
#   inflating: kaggle/facial_keypoints_detection/IdLookupTable.csv
#   inflating: kaggle/facial_keypoints_detection/SampleSubmission.csv
#   inflating: kaggle/facial_keypoints_detection/test.zip
#   inflating: kaggle/facial_keypoints_detection/training.zip

# %%
# !unzip /content/kaggle/facial_keypoints_detection/test.zip -d kaggle/facial_keypoints_detection
# !unzip /content/kaggle/facial_keypoints_detection/training.zip -d kaggle/facial_keypoints_detection
# Out:
# Archive:  /content/kaggle/facial_keypoints_detection/test.zip
#   inflating: kaggle/facial_keypoints_detection/test.csv
# Archive:  /content/kaggle/facial_keypoints_detection/training.zip
#   inflating: kaggle/facial_keypoints_detection/training.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
df_train = pd.read_csv('/content/kaggle/facial_keypoints_detection/training.csv')
df_test = pd.read_csv('/content/kaggle/facial_keypoints_detection/test.csv')

df_train.shape, df_test.shape
# Out:
# ((7049, 31), (1783, 2))

# %%
df_train.head()
# Out:
#    left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0          66.033564          39.002274           30.227008
# 1          64.332936          34.970077           29.949277
# 2          65.057053          34.909642           30.903789
# 3          65.225739          37.261774           32.023096
# 4          66.725301          39.621261           32.244810
#
#    right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0           36.421678                59.582075                39.647423
# 1           33.448715                58.856170                35.274349
# 2           34.909642                59.412000                36.320968
# 3           37.261774                60.003339                39.127179
# 4           38.042032                58.565890                39.621261
#
#    left_eye_outer_corner_x  left_eye_outer_corner_y  right_eye_inner_corner_x  \
# 0                73.130346                39.969997                 36.356571
# ...

# %%
df_test.head()
# Out:
#    ImageId                                              Image
# 0        1  182 183 182 182 180 180 176 169 156 137 124 10...
# 1        2  76 87 81 72 65 59 64 76 69 42 31 38 49 58 58 4...
# 2        3  177 176 174 170 169 169 168 166 166 166 161 14...
# 3        4  176 174 174 175 174 174 176 176 175 171 165 15...
# 4        5  50 47 44 101 144 149 120 58 48 42 35 35 37 39 ...
